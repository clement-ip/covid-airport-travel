# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys, os
import glob

# %%
# Take all 220 csv files and merge it into one big dataframe
# Eventually we would want to split the dataframe into three csvs - 
# canada, usa, and north america

# %%
# Find path of current working directory
# https://stackoverflow.com/questions/58274401/importing-multiple-csv-files-into-pandas-and-merge-them-into-one-dataframe
path = os.getcwd()
all_files = glob.glob(path + "/*.csv")
dfs = list()

for file in all_files:
    print(file)
    df = pd.read_csv(file)
    dfs.append(df)

# some files have different columns; need to fix 
frame = pd.concat(dfs, axis = 0, ignore_index = True, sort = True)
df.head()
# Out:
# /home/aytang/sfuhome/353project/coviddata/10-17-2020.csv
# /home/aytang/sfuhome/353project/coviddata/10-14-2020.csv
# /home/aytang/sfuhome/353project/coviddata/10-16-2020.csv
# /home/aytang/sfuhome/353project/coviddata/10-13-2020.csv
# /home/aytang/sfuhome/353project/coviddata/10-15-2020.csv
# /home/aytang/sfuhome/353project/coviddata/10-11-2020.csv
# /home/aytang/sfuhome/353project/coviddata/10-12-2020.csv
# /home/aytang/sfuhome/353project/coviddata/10-08-2020.csv
# /home/aytang/sfuhome/353project/coviddata/10-09-2020.csv
# /home/aytang/sfuhome/353project/coviddata/10-10-2020.csv
# /home/aytang/sfuhome/353project/coviddata/10-07-2020.csv
# /home/aytang/sfuhome/353project/coviddata/10-05-2020.csv
# /home/aytang/sfuhome/353project/coviddata/10-06-2020.csv
# /home/aytang/sfuhome/353project/coviddata/10-02-2020.csv
# /home/aytang/sfuhome/353project/coviddata/09-30-2020.csv
# /home/aytang/sfuhome/353project/coviddata/09-29-2020.csv
# ...

# %%
df_filtered = df.loc[(df["Country_Region"] == "US") | (df["Country_Region"] == "Canada")]

# %%
df
# Out:
#       FIPS Admin2                Province_State          Country_Region  \
# 0      NaN    NaN                           NaN             Afghanistan
# 1      NaN    NaN                           NaN                 Albania
# 2      NaN    NaN                           NaN                 Algeria
# 3      NaN    NaN                           NaN                 Andorra
# 4      NaN    NaN                           NaN                  Angola
# 5      NaN    NaN                           NaN     Antigua and Barbuda
# 6      NaN    NaN                           NaN               Argentina
# 7      NaN    NaN                           NaN                 Armenia
# 8      NaN    NaN  Australian Capital Territory               Australia
# 9      NaN    NaN               New South Wales               Australia
# 10     NaN    NaN            Northern Territory               Australia
# 11     NaN    NaN                    Queensland               Australia
# ...

# %%
df_filtered
# Out:
#          FIPS       Admin2             Province_State Country_Region  \
# 65        NaN          NaN                    Alberta         Canada
# 66        NaN          NaN           British Columbia         Canada
# 67        NaN          NaN           Diamond Princess         Canada
# 68        NaN          NaN             Grand Princess         Canada
# 69        NaN          NaN                   Manitoba         Canada
# 70        NaN          NaN              New Brunswick         Canada
# 71        NaN          NaN  Newfoundland and Labrador         Canada
# 72        NaN          NaN      Northwest Territories         Canada
# 73        NaN          NaN                Nova Scotia         Canada
# 74        NaN          NaN                    Ontario         Canada
# 75        NaN          NaN       Prince Edward Island         Canada
# 76        NaN          NaN                     Quebec         Canada
# 77        NaN          NaN               Saskatchewan         Canada
# ...
