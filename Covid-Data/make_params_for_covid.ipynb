# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd
import shapely
import seaborn as sns

# %%
atlCases = pd.read_csv('atlCases.csv')
jfkCases = pd.read_csv('jfkCases.csv')
lgaCases = pd.read_csv('lgaCases.csv')
seaCases = pd.read_csv('seaCases.csv')
laxCases = pd.read_csv('laxCases.csv')
yvrCases = pd.read_csv('yvrCases.csv')
yegCases = pd.read_csv('yegCases.csv')
yyzCases = pd.read_csv('yyzCases.csv')
yulCases = pd.read_csv('yulCases.csv')

# %%
yegCt = yegCases.groupby(["Province/State", "Date"])["Confirmed"].sum().reset_index(name = "Count")
yegCt = pd.concat([yegCases, yegCt['Count']], axis = 1)
temp = yegCt.shift(1)
yegCt['Difference'] = yegCt['Count'] - temp['Count']
yegCt
# Out:
#      Unnamed: 0  Active  Case-Fatality_Ratio     Combined_Key  Confirmed  \
# 0             0     0.0                  NaN  Alberta, Canada        259
# 1             1     0.0                  NaN  Alberta, Canada        301
# 2             2     0.0                  NaN  Alberta, Canada        359
# 3             3     0.0                  NaN  Alberta, Canada        358
# 4             4     0.0                  NaN  Alberta, Canada        486
# 5             5     0.0                  NaN  Alberta, Canada        542
# 6             6     0.0                  NaN  Alberta, Canada        542
# 7             7     0.0                  NaN  Alberta, Canada        621
# 8             8     0.0                  NaN  Alberta, Canada        661
# 9             9     0.0                  NaN  Alberta, Canada        690
# 10           10     0.0                  NaN  Alberta, Canada        754
# 11           11     0.0                  NaN  Alberta, Canada        969
# ...

# %%
yvrCt = yvrCases.groupby(["Province/State", "Date"])["Confirmed"].sum().reset_index(name = "Count")
yvrCt = pd.concat([yvrCases, yvrCt['Count']], axis = 1)
temp = yvrCt.shift(1)
yvrCt['Difference'] = yvrCt['Count'] - temp['Count']
yvrCt
# Out:
#      Unnamed: 0  Active  Case-Fatality_Ratio              Combined_Key  \
# 0             0     0.0                  NaN  British Columbia, Canada
# 1             1     0.0                  NaN  British Columbia, Canada
# 2             2     0.0                  NaN  British Columbia, Canada
# 3             3     0.0                  NaN  British Columbia, Canada
# 4             4     0.0                  NaN  British Columbia, Canada
# 5             5     0.0                  NaN  British Columbia, Canada
# 6             6     0.0                  NaN  British Columbia, Canada
# 7             7     0.0                  NaN  British Columbia, Canada
# 8             8     0.0                  NaN  British Columbia, Canada
# 9             9     0.0                  NaN  British Columbia, Canada
# 10           10     0.0                  NaN  British Columbia, Canada
# 11           11     0.0                  NaN  British Columbia, Canada
# ...

# %%
yulCt = yulCases.groupby(["Province/State", "Date"])["Confirmed"].sum().reset_index(name = "Count")
yulCt = pd.concat([yulCases, yulCt['Count']], axis = 1)
temp = yulCt.shift(1)
yulCt['Difference'] = yulCt['Count'] - temp['Count']
yulCt
# Out:
#      Unnamed: 0   Active  Case-Fatality_Ratio    Combined_Key  Confirmed  \
# 0             0      0.0                  NaN  Quebec, Canada        219
# 1             1      0.0                  NaN  Quebec, Canada        628
# 2             2      0.0                  NaN  Quebec, Canada       1013
# 3             3      0.0                  NaN  Quebec, Canada       1342
# 4             4      0.0                  NaN  Quebec, Canada       1632
# 5             5      0.0                  NaN  Quebec, Canada       2024
# 6             6      0.0                  NaN  Quebec, Canada       2498
# 7             7      0.0                  NaN  Quebec, Canada       2840
# 8             8      0.0                  NaN  Quebec, Canada       3430
# 9             9      0.0                  NaN  Quebec, Canada       4162
# 10           10      0.0                  NaN  Quebec, Canada       4611
# 11           11      0.0                  NaN  Quebec, Canada       5518
# ...

# %%
yyzCt = yyzCases.groupby(["Province/State", "Date"])["Confirmed"].sum().reset_index(name = "Count")
yyzCt = pd.concat([yyzCases, yyzCt['Count']], axis = 1)
temp = yyzCt.shift(1)
yyzCt['Difference'] = yyzCt['Count'] - temp['Count']
yyzCt
# Out:
#      Unnamed: 0   Active  Case-Fatality_Ratio     Combined_Key  Confirmed  \
# 0             0      0.0                  NaN  Ontario, Canada        425
# 1             1      0.0                  NaN  Ontario, Canada        503
# 2             2      0.0                  NaN  Ontario, Canada        588
# 3             3      0.0                  NaN  Ontario, Canada        688
# 4             4      0.0                  NaN  Ontario, Canada        858
# 5             5      0.0                  NaN  Ontario, Canada        994
# 6             6      0.0                  NaN  Ontario, Canada       1144
# 7             7      0.0                  NaN  Ontario, Canada       1355
# 8             8      0.0                  NaN  Ontario, Canada       1706
# 9             9      0.0                  NaN  Ontario, Canada       1966
# 10           10      0.0                  NaN  Ontario, Canada       2392
# 11           11      0.0                  NaN  Ontario, Canada       2793
# ...

# %%
# For American Count/Difference - Aggregate by State and not by each county
lgaCt = lgaCases.groupby(["Province/State", "Date"])["Confirmed"].sum().reset_index(name = "Count")
lgaCt = pd.concat([lgaCases, lgaCt['Count']], axis = 1)
temp = lgaCt.shift(1)
lgaCt['Difference'] = lgaCt['Count'] - temp['Count']
lgaCt
# Out:
#        Unnamed: 0   Active  Case-Fatality_Ratio                 Combined_Key  \
# 0               0      0.0                  NaN  New York City, New York, US
# 1               1      0.0                  NaN    Westchester, New York, US
# 2               2      0.0                  NaN       Rockland, New York, US
# 3               3      0.0                  NaN         Orange, New York, US
# 4               4      0.0                  NaN         Albany, New York, US
# 5               5      0.0                  NaN       Dutchess, New York, US
# 6               6      0.0                  NaN         Monroe, New York, US
# 7               7      0.0                  NaN           Erie, New York, US
# 8               8      0.0                  NaN       Onondaga, New York, US
# 9               9      0.0                  NaN       Saratoga, New York, US
# 10             10      0.0                  NaN    Schenectady, New York, US
# ...

# %%
jfkCt = jfkCases.groupby(["Province/State", "Date"])["Confirmed"].sum().reset_index(name = "Count")
jfkCt = pd.concat([jfkCases, jfkCt['Count']], axis = 1)
temp = jfkCt.shift(1)
jfkCt['Difference'] = jfkCt['Count'] - temp['Count']
jfkCt
# Out:
#      Unnamed: 0   Active  Case-Fatality_Ratio           Combined_Key  \
# 0             1      0.0                  NaN   Nassau, New York, US
# 1             3      0.0                  NaN  Suffolk, New York, US
# 2          2343      0.0                  NaN    Kings, New York, US
# 3          2344      0.0                  NaN    Lewis, New York, US
# 4          2349      0.0                  NaN   Queens, New York, US
# 5          4688      0.0                  NaN    Kings, New York, US
# 6          4825      0.0                  NaN    Lewis, New York, US
# 7          5221      0.0                  NaN   Nassau, New York, US
# 8          5548      0.0                  NaN   Queens, New York, US
# 9          5896      0.0                  NaN  Suffolk, New York, US
# 10         7862      0.0                  NaN    Kings, New York, US
# 11         7999      0.0                  NaN    Lewis, New York, US
# 12         8395      0.0                  NaN   Nassau, New York, US
# ...

# %%
atlCt = atlCases.groupby(["Province/State", "Date"])["Confirmed"].sum().reset_index(name = "Count")
atlCt = pd.concat([atlCases, atlCt['Count']], axis = 1)
temp = atlCt.shift(1)
atlCt['Difference'] = atlCt['Count'] - temp['Count']
atlCt
# Out:
#        Unnamed: 0  Active  Case-Fatality_Ratio             Combined_Key  \
# 0               0     0.0                  NaN        Cobb, Georgia, US
# 1               1     0.0                  NaN      DeKalb, Georgia, US
# 2               2     0.0                  NaN   Dougherty, Georgia, US
# 3               3     0.0                  NaN    Gwinnett, Georgia, US
# 4               4     0.0                  NaN         Lee, Georgia, US
# 5               5     0.0                  NaN     Clayton, Georgia, US
# 6               6     0.0                  NaN       Floyd, Georgia, US
# 7               7     0.0                  NaN      Clarke, Georgia, US
# 8               8     0.0                  NaN        Hall, Georgia, US
# 9               9     0.0                  NaN     Lowndes, Georgia, US
# 10             10     0.0                  NaN       Henry, Georgia, US
# 11             11     0.0                  NaN    Paulding, Georgia, US
# ...

# %%
laxCt = laxCases.groupby(["Province/State", "Date"])["Confirmed"].sum().reset_index(name = "Count")
laxCt = pd.concat([laxCases, laxCt['Count']], axis = 1)
temp = laxCt.shift(1)
laxCt['Difference'] = laxCt['Count'] - temp['Count']
laxCt
# Out:
#       Unnamed: 0    Active  Case-Fatality_Ratio  \
# 0              0       0.0                  NaN
# 1              1       0.0                  NaN
# 2              2       0.0                  NaN
# 3              3       0.0                  NaN
# 4              4       0.0                  NaN
# 5              5       0.0                  NaN
# 6              6       0.0                  NaN
# 7              7       0.0                  NaN
# 8              8       0.0                  NaN
# 9              9       0.0                  NaN
# 10            10       0.0                  NaN
# 11            11       0.0                  NaN
# 12            12       0.0                  NaN
# 13            13       0.0                  NaN
# 14            14       0.0                  NaN
# 15            15       0.0                  NaN
# 16            16       0.0                  NaN
# 17            17       0.0                  NaN
# ...

# %%
seaCt = seaCases.groupby(["Province/State", "Date"])["Confirmed"].sum().reset_index(name = "Count")
seaCt = pd.concat([seaCases, seaCt['Count']], axis = 1)
temp = seaCt.shift(1)
seaCt['Difference'] = seaCt['Count'] - temp['Count']
seaCt
# Out:
#       Unnamed: 0   Active  Case-Fatality_Ratio  \
# 0              0      0.0                  NaN
# 1              1      0.0                  NaN
# 2              2      0.0                  NaN
# 3              3      0.0                  NaN
# 4              4      0.0                  NaN
# 5              5      0.0                  NaN
# 6              6      0.0                  NaN
# 7              7      0.0                  NaN
# 8              8      0.0                  NaN
# 9              9      0.0                  NaN
# 10            10      0.0                  NaN
# 11            11      0.0                  NaN
# 12            12      0.0                  NaN
# 13            13      0.0                  NaN
# 14            14      0.0                  NaN
# 15            15      0.0                  NaN
# 16            16      0.0                  NaN
# 17            17      0.0                  NaN
# 18            18      0.0                  NaN
# ...

# %%
lgaCt.to_csv('lgaCases.csv')
jfkCt.to_csv('jfkCases.csv')
seaCt.to_csv('seaCases.csv')
atlCt.to_csv('atlCases.csv')
laxCt.to_csv('laxCases.csv')
yvrCt.to_csv('yvrCases.csv')
yegCt.to_csv('yegCases.csv')
yyzCt.to_csv('yyzCases.csv')
yulCt.to_csv('yulCases.csv')
