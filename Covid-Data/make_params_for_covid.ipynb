# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd
import shapely
import seaborn as sns

# %%
# Modify COVID dataframes and added more parameters to it - 
# Difference: Increase/decrease in new infections from the day before within the state/province

# %%
atlCases = pd.read_csv('atlCases.csv')
jfkCases = pd.read_csv('jfkCases.csv')
lgaCases = pd.read_csv('lgaCases.csv')
seaCases = pd.read_csv('seaCases.csv')
laxCases = pd.read_csv('laxCases.csv')
yvrCases = pd.read_csv('yvrCases.csv')
yegCases = pd.read_csv('yegCases.csv')
yyzCases = pd.read_csv('yyzCases.csv')
yulCases = pd.read_csv('yulCases.csv')

# %%
temp = yegCases.shift(1)
yegCases['Difference'] = yegCases['Confirmed'] - temp['Confirmed']
#yegCases = yegCases.drop(columns = ['Count'])
yegCases = yegCases.loc[:,~(yegCases.columns.str.contains("Unnamed:"))]
yegCases
# Out:
#      Active  Case-Fatality_Ratio     Combined_Key  Confirmed Country/Region  \
# 0       0.0                  NaN  Alberta, Canada        259         Canada
# 1       0.0                  NaN  Alberta, Canada        301         Canada
# 2       0.0                  NaN  Alberta, Canada        359         Canada
# 3       0.0                  NaN  Alberta, Canada        358         Canada
# 4       0.0                  NaN  Alberta, Canada        486         Canada
# 5       0.0                  NaN  Alberta, Canada        542         Canada
# 6       0.0                  NaN  Alberta, Canada        542         Canada
# 7       0.0                  NaN  Alberta, Canada        621         Canada
# 8       0.0                  NaN  Alberta, Canada        661         Canada
# 9       0.0                  NaN  Alberta, Canada        690         Canada
# 10      0.0                  NaN  Alberta, Canada        754         Canada
# ...

# %%
temp = yvrCases.shift(1)
yvrCases['Difference'] = yvrCases['Confirmed'] - temp['Confirmed']
#yvrCases = yvrCases.drop(columns = ['Count'])
yvrCases = yvrCases.loc[:,~(yvrCases.columns.str.contains("Unnamed:"))]
yvrCases
# Out:
#      Active  Case-Fatality_Ratio              Combined_Key  Confirmed  \
# 0       0.0                  NaN  British Columbia, Canada        424
# 1       0.0                  NaN  British Columbia, Canada        472
# 2       0.0                  NaN  British Columbia, Canada        617
# 3       0.0                  NaN  British Columbia, Canada        617
# 4       0.0                  NaN  British Columbia, Canada        725
# 5       0.0                  NaN  British Columbia, Canada        725
# 6       0.0                  NaN  British Columbia, Canada        884
# 7       0.0                  NaN  British Columbia, Canada        884
# 8       0.0                  NaN  British Columbia, Canada        970
# 9       0.0                  NaN  British Columbia, Canada       1013
# 10      0.0                  NaN  British Columbia, Canada       1013
# 11      0.0                  NaN  British Columbia, Canada       1121
# ...

# %%
temp = yulCases.shift(1)
yulCases['Difference'] = yulCases['Confirmed'] - temp['Confirmed']
#yulCases = yulCases.drop(columns = ['Count'])
yulCases = yulCases.loc[:,~(yulCases.columns.str.contains("Unnamed:"))]
yulCases
# Out:
#       Active  Case-Fatality_Ratio    Combined_Key  Confirmed Country/Region  \
# 0        0.0                  NaN  Quebec, Canada        219         Canada
# 1        0.0                  NaN  Quebec, Canada        628         Canada
# 2        0.0                  NaN  Quebec, Canada       1013         Canada
# 3        0.0                  NaN  Quebec, Canada       1342         Canada
# 4        0.0                  NaN  Quebec, Canada       1632         Canada
# 5        0.0                  NaN  Quebec, Canada       2024         Canada
# 6        0.0                  NaN  Quebec, Canada       2498         Canada
# 7        0.0                  NaN  Quebec, Canada       2840         Canada
# 8        0.0                  NaN  Quebec, Canada       3430         Canada
# 9        0.0                  NaN  Quebec, Canada       4162         Canada
# 10       0.0                  NaN  Quebec, Canada       4611         Canada
# ...

# %%
temp = yyzCases.shift(1)
yyzCases['Difference'] = yyzCases['Confirmed'] - temp['Confirmed']
#yyzCases = yyzCases.drop(columns = ['Count'])
yyzCases = yyzCases.loc[:,~(yyzCases.columns.str.contains("Unnamed:"))]
yyzCases
# Out:
#       Active  Case-Fatality_Ratio     Combined_Key  Confirmed Country/Region  \
# 0        0.0                  NaN  Ontario, Canada        425         Canada
# 1        0.0                  NaN  Ontario, Canada        503         Canada
# 2        0.0                  NaN  Ontario, Canada        588         Canada
# 3        0.0                  NaN  Ontario, Canada        688         Canada
# 4        0.0                  NaN  Ontario, Canada        858         Canada
# 5        0.0                  NaN  Ontario, Canada        994         Canada
# 6        0.0                  NaN  Ontario, Canada       1144         Canada
# 7        0.0                  NaN  Ontario, Canada       1355         Canada
# 8        0.0                  NaN  Ontario, Canada       1706         Canada
# 9        0.0                  NaN  Ontario, Canada       1966         Canada
# 10       0.0                  NaN  Ontario, Canada       2392         Canada
# ...

# %%
# For American Count/Difference - 
# The 'Difference' column is aggregated by counties and not states

lgaCases = lgaCases.sort_values(by = ['County', 'Date'])
temp = lgaCases.shift(1)
lgaCases['Difference'] = lgaCases['Confirmed'] - temp['Confirmed']
lgaCases = lgaCases.loc[:,~(lgaCases.columns.str.contains("Unnamed:"))]
lgaCases
# Out:
#        Active  Case-Fatality_Ratio          Combined_Key  Confirmed  \
# 0         0.0                  NaN  Albany, New York, US        123
# 1         0.0                  NaN  Albany, New York, US        127
# 2         0.0                  NaN  Albany, New York, US        146
# 3         0.0                  NaN  Albany, New York, US        152
# 4         0.0                  NaN  Albany, New York, US        171
# 5         0.0                  NaN  Albany, New York, US        187
# 6         0.0                  NaN  Albany, New York, US        195
# 7         0.0                  NaN  Albany, New York, US        205
# 8         0.0                  NaN  Albany, New York, US        217
# 9         0.0                  NaN  Albany, New York, US        226
# 10        0.0                  NaN  Albany, New York, US        240
# 11        0.0                  NaN  Albany, New York, US        253
# 12        0.0                  NaN  Albany, New York, US        267
# ...

# %%
jfkCases = jfkCases.sort_values(by = ['County', 'Date'])
temp = jfkCases.shift(1)
jfkCases['Difference'] = jfkCases['Confirmed'] - temp['Confirmed']
jfkCases = jfkCases.loc[:,~(jfkCases.columns.str.contains("Unnamed:"))]
jfkCases
# Out:
#       Active  Case-Fatality_Ratio           Combined_Key  Confirmed  \
# 0        0.0                  NaN    Kings, New York, US          0
# 1        0.0                  NaN    Kings, New York, US          0
# 2        0.0                  NaN    Kings, New York, US          0
# 3        0.0                  NaN    Kings, New York, US          0
# 4        0.0                  NaN    Kings, New York, US          0
# 5        0.0                  NaN    Kings, New York, US          0
# 6        0.0                  NaN    Kings, New York, US          0
# 7        0.0                  NaN    Kings, New York, US          0
# 8        0.0                  NaN    Kings, New York, US          0
# 9    57708.0            11.215730    Kings, New York, US      64998
# 10   57828.0            11.195061    Kings, New York, US      65118
# 11   57911.0            11.180810    Kings, New York, US      65201
# 12   58039.0            11.157543    Kings, New York, US      65328
# ...

# %%
atlCases = atlCases.sort_values(by = ['County', 'Date'])
temp = atlCases.shift(1)
atlCases['Difference'] = atlCases['Confirmed'] - temp['Confirmed']
atlCases = atlCases.loc[:,~(atlCases.columns.str.contains("Unnamed:"))]
atlCases
# Out:
#        Active  Case-Fatality_Ratio            Combined_Key  Confirmed  \
# 0         0.0                  NaN    Appling, Georgia, US          0
# 1         0.0                  NaN    Appling, Georgia, US          0
# 2         0.0                  NaN    Appling, Georgia, US          0
# 3         0.0                  NaN    Appling, Georgia, US          1
# 4         0.0                  NaN    Appling, Georgia, US          0
# 5         0.0                  NaN    Appling, Georgia, US          0
# 6         0.0                  NaN    Appling, Georgia, US          0
# 7         0.0                  NaN    Appling, Georgia, US          0
# 8         0.0                  NaN    Appling, Georgia, US          0
# 9         0.0                  NaN    Appling, Georgia, US          2
# 10        0.0                  NaN    Appling, Georgia, US          1
# 11        0.0                  NaN    Appling, Georgia, US          3
# ...

# %%
laxCases = laxCases.sort_values(by = ['County', 'Date'])
temp = laxCases.shift(1)
laxCases['Difference'] = laxCases['Confirmed'] - temp['Confirmed']
laxCases = laxCases.loc[:,~(laxCases.columns.str.contains("Unnamed:"))]
laxCases
# Out:
#       Active  Case-Fatality_Ratio            Combined_Key  Confirmed  \
# 0        0.0                  NaN  Alpine, California, US          0
# 1        0.0                  NaN  Alpine, California, US          0
# 2        0.0                  NaN  Alpine, California, US          0
# 3        0.0                  NaN  Alpine, California, US          0
# 4        0.0                  NaN  Alpine, California, US          0
# 5        0.0                  NaN  Alpine, California, US          0
# 6        0.0                  NaN  Alpine, California, US          0
# 7        0.0                  NaN  Alpine, California, US          0
# 8        0.0                  NaN  Alpine, California, US          0
# 9        0.0                  NaN  Alpine, California, US          1
# 10       0.0                  NaN  Alpine, California, US          1
# 11       0.0                  NaN  Alpine, California, US          1
# 12       0.0                  NaN  Alpine, California, US          1
# ...

# %%
seaCases = seaCases.sort_values(by = ['County', 'Date'])
temp = seaCases.shift(1)
seaCases['Difference'] = seaCases['Confirmed'] - temp['Confirmed']
#seaCases = seaCases.drop(columns = ['Count'])
seaCases = seaCases.loc[:,~(seaCases.columns.str.contains("Unnamed:"))]
seaCases
# Out:
#        Active  Case-Fatality_Ratio            Combined_Key  Confirmed  \
# 0         0.0                  NaN   Adams, Washington, US          0
# 1         0.0                  NaN   Adams, Washington, US          1
# 2         0.0                  NaN   Adams, Washington, US          1
# 3         0.0                  NaN   Adams, Washington, US          1
# 4         0.0                  NaN   Adams, Washington, US          3
# 5         0.0                  NaN   Adams, Washington, US          3
# 6         0.0                  NaN   Adams, Washington, US          5
# 7         0.0                  NaN   Adams, Washington, US          5
# 8         0.0                  NaN   Adams, Washington, US          7
# 9         0.0                  NaN   Adams, Washington, US         13
# 10        0.0                  NaN   Adams, Washington, US         14
# 11        0.0                  NaN   Adams, Washington, US         20
# ...

# %%
#Do Not Run This Unless Sure --> this will overwrite input files!!!
"""lgaCases.to_csv('lgaCases.csv')
jfkCases.to_csv('jfkCases.csv')
seaCases.to_csv('seaCases.csv')
atlCases.to_csv('atlCases.csv')
laxCases.to_csv('laxCases.csv')
yvrCases.to_csv('yvrCases.csv')
yegCases.to_csv('yegCases.csv')
yyzCases.to_csv('yyzCases.csv')
yulCases.to_csv('yulCases.csv')"""
